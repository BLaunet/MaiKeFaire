# %%
from sncf_crawler.crawler import SncfCrawler
from sncf_crawler.discountCards import discountCards
import datetime

# %%
trip = SncfCrawler('paris', 'auray', discountCard=discountCards.CARTE_JEUNE)

# %%
startDate='2020-02-01'
endDate='2020-02-05'
df = trip.getProposals(startDate, endDate)

# %%
df
# Out:
#           departureDate          arrivalDate trainNumber  firstClassMinPrice  \
# 0   2020-02-01T08:57:00  2020-02-01T11:47:00        8707                67.0
# 1   2020-02-01T10:57:00  2020-02-01T13:43:00        8715                62.0
# 2   2020-02-01T13:00:00  2020-02-01T15:46:00        8719                67.0
# 3   2020-02-01T16:57:00  2020-02-01T19:46:00        8729                82.0
# 4   2020-02-01T18:57:00  2020-02-01T21:50:00        8739                98.0
# 5   2020-02-02T08:57:00  2020-02-02T11:47:00        8707                49.0
# 6   2020-02-02T10:57:00  2020-02-02T13:46:00        8715                49.0
# 7   2020-02-02T13:00:00  2020-02-02T15:48:00        8719                49.0
# 8   2020-02-02T15:05:00  2020-02-02T17:46:00        8725                49.0
# 9   2020-02-02T16:57:00  2020-02-02T19:46:00        8729                92.0
# 10  2020-02-02T18:57:00  2020-02-02T21:46:00        8741                77.0
# ...
